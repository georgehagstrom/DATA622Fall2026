# %%
import pandas as pd
import numpy as np
import nflreadpy as nfl
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import poisson
from sklearn.linear_model import PoissonRegressor
from sklearn.model_selection import TimeSeriesSplit
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.model_selection import KFold
from scipy.stats import poisson
from statsmodels.discrete.discrete_model import GeneralizedPoisson # Not gonna use it but its a little better
from sklearn.utils import resample

# I like to have the okabe ito colors, sort of 

from okabeito import lightblue, yellow, orange, green, purple, red, blue, black

# %%
pbp_pass = nfl.load_pbp(list(range(2006,2024))).to_pandas()

# %%
pbp_pass = pbp_pass.query("passer_id.notnull()").reset_index(drop=True)


pbp_pass.loc[pbp_pass.pass_touchdown.isnull(),"pass_touchdown"] = 0
pbp_pass.loc[pbp_pass.passer.isnull(),"passer"] = "none"


pbp_pass["team_spread"] = np.where(pbp_pass["posteam_type"] == "home",pbp_pass["spread_line"],-pbp_pass["spread_line"])


qb_game = (
    pbp_pass
    .groupby(["season","week","passer_id","passer"])
    .agg(pass_td = ('pass_touchdown',"sum"),
        n_passes = ('pass_touchdown','count'),
        total_line = ('total_line','first'),
        team_line =  ('team_spread','first'),
        air_yards= ("air_yards","sum"),
        interceptions = ("interception","sum"),
        completions = ("complete_pass","sum"),
        passing_yards = ("passing_yards","sum"),
        posteam_type = ("posteam_type","first"),
        season_type = ("season_type","first") )
    .reset_index()
    .query("n_passes >= 10")

)

# %%
rows = []
for season_idx in range(2006,2024):
    for week_idx in range(1,23):

        #mask = (qb_game["season"] == season_idx - 1) | ( (qb_game["season"] == season_idx) & (qb_game["week"] < week_idx))

        mask = (
            (qb_game["season"] == season_idx - 1) |
            ((qb_game["season"] == season_idx) &
            (qb_game["week"] < week_idx))
        )

        filtered_qb_game = (
            qb_game.loc[mask]
            .groupby(['passer_id',"passer"])
            .agg(n_games = ("pass_td","count"),
                 pass_td_rate = ("pass_td","mean"),
                 air_yards_pg = ("air_yards","mean"),
                 inteceptions_pg = ("interceptions","mean"),
                 completions_pg = ("completions","mean"),
                 passing_yards_pg = ("passing_yards","mean"))
            .reset_index()
            .assign(season = season_idx,week=week_idx))
        
        rows.append(filtered_qb_game) 

x_features = pd.concat(rows,ignore_index=True)

# %%
x_features
# Out:
#         passer_id        passer  n_games  pass_td_rate  air_yards_pg  inteceptions_pg  completions_pg  passing_yards_pg  season  week
# 0      00-0000865       C.Batch        1      3.000000    233.000000         0.000000       15.000000        209.000000    2006     2
# 1      00-0001361     D.Bledsoe        1      1.000000    304.000000         3.000000       16.000000        246.000000    2006     2
# 2      00-0001823      A.Brooks        1      0.000000    144.000000         0.000000        6.000000         68.000000    2006     2
# 3      00-0002110     M.Brunell        1      0.000000    174.000000         0.000000       17.000000        163.000000    2006     2
# 4      00-0003292     K.Collins        1      0.000000    291.000000         2.000000       17.000000        223.000000    2006     2
# ...           ...           ...      ...           ...           ...              ...             ...               ...     ...   ...
# 28705  00-0038598        J.Hall        1      0.000000    113.000000         1.000000        5.000000         67.000000    2023    22
# 28706  00-0039150       B.Young       16      0.687500    250.562500         0.625000       19.687500        179.812500    2023    22
# 28707  00-0039152       W.Levis        8      1.000000    322.750000         0.500000       18.375000        224.000000    2023    22
# 28708  00-0039163      C.Stroud       17      1.529412    288.882353         0.294118       20.823529        268.058824    2023    22
# 28709  00-0039164  A.Richardson        4      0.750000    169.000000         0.250000       12.500000        144.250000    2023    22
#
# [28710 rows x 10 columns]

# %%
rolling_features_df = (
    qb_game.query("season >= 2007")
    .merge(x_features,on = ["season","week","passer_id","passer"],how="inner")
    .sort_values(["season","week","passer_id"])
)

# %%
rolling_features_df["is_home"] = (rolling_features_df["posteam_type"] == "home").astype(int)
rolling_features_df["is_playoff"] = (rolling_features_df["season_type"] == "POST").astype(int)

# %%
qb_game.groupby("pass_td").size()
# Out:
# pass_td
# 0.0    2410
# 1.0    3492
# 2.0    2571
# 3.0    1188
# 4.0     399
# 5.0      75
# 6.0      17
# 7.0       3
# dtype: int64

# %%
rolling_features_df
# Out:
#       season  week   passer_id        passer  pass_td  n_passes  total_line  team_line  air_yards  interceptions  ...  posteam_type  season_type n_games pass_td_rate  \
# 0       2007     1  00-0004161    J.Delhomme      3.0        30        43.0       -1.5      229.0            0.0  ...          away          REG      13     1.307692
# 1       2007     1  00-0005106       B.Favre      0.0        47        41.5       -3.0      421.0            1.0  ...          home          REG      16     1.125000
# 2       2007     1  00-0005755      J.Garcia      0.0        34        40.5       -6.0      226.0            0.0  ...          away          REG       8     1.500000
# 3       2007     1  00-0006355       T.Green      1.0        42        34.0       -3.0      248.0            0.0  ...          away          REG       9     0.888889
# 4       2007     1  00-0007091  M.Hasselbeck      1.0        28        40.5        6.0      192.0            0.0  ...          home          REG      14     1.500000
# ...      ...   ...         ...           ...      ...       ...         ...        ...        ...            ...  ...           ...          ...     ...          ...
# 9276    2023    21  00-0033873     P.Mahomes      1.0        50        44.0       -4.5      233.0            0.0  ...          away         POST      38     2.052632
# 9277    2023    21  00-0034796     L.Jackson      1.0        47        44.0        4.5      344.0            1.0  ...          home         POST      28     1.535714
# 9278    2023    21  00-0037834       B.Purdy      1.0        36        52.5        7.5      283.0            1.0  ...          home         POST      26     1.846154
# 9279    2023    22  00-0033873     P.Mahomes      2.0        55        47.0       -1.5      280.0            1.0  ...          home         POST      39     2.025641
# 9280    2023    22  00-0037834       B.Purdy      1.0        43        47.0        1.5      324.0            0.0  ...          away         POST      27     1.814815
#
#       air_yards_pg  inteceptions_pg  completions_pg  passing_yards_pg  is_home  is_playoff
# 0       263.384615         0.846154       20.230769        215.769231        0           0
# 1       331.562500         1.125000       21.437500        242.812500        1           0
# 2       274.125000         0.250000       18.375000        209.125000        0           0
# 3       199.555556         1.222222       15.000000        161.000000        0           0
# 4       320.357143         1.285714       17.571429        205.500000        1           0
# ...            ...              ...             ...               ...      ...         ...
# 9276    254.368421         0.684211       24.947368        279.289474        0           1
# 9277    240.857143         0.500000       18.678571        216.464286        1           1
# 9278    218.884615         0.576923       18.538462        248.153846        1           1
# 9279    253.820513         0.666667       25.076923        278.307692        1           1
# 9280    221.259259         0.592593       18.592593        248.851852        0           1
#
# [9281 rows x 22 columns]

# %%
X_base = rolling_features_df[["pass_td_rate","total_line"]].values
y = rolling_features_df["pass_td"].values


model_simple_full = PoissonRegressor(alpha=0,max_iter=1000)

model_simple_full.fit(X_base,y)
# Out:
# PoissonRegressor(alpha=0, max_iter=1000)

# %%
model_simple_full.coef_
# Out:
# array([0.30939192, 0.02309926])

# %%
obs_p = pd.Series(y)

# %%
td_counts = np.arange(7)

mu = model_simple_full.predict(X_base)
probs = np.column_stack([poisson.pmf(k,mu)  for k in td_counts ])
marginal_probs = probs.mean(axis=0)
obs_p = pd.Series(y).value_counts(normalize=True).sort_index()





count_df = pd.DataFrame({
    "Observed":[obs_p.get(k,0) for k in td_counts],
    "Base Poisson Model": marginal_probs
})

count_df.plot.bar(color=[blue,orange],figsize=(8,6))
# Out:
# <Axes: >

# %%
kf_random = KFold(n_splits=5, shuffle=True,random_state=65)


pw_all = []


for tr, te in kf_random.split(X_base):
    model_basic = PoissonRegressor(alpha=0, max_iter=1000)
    model_basic.fit(X_base[tr],y[tr])
    mu = model_basic.predict(X_base[te])
    score = poisson.logpmf(y[te],mu)
    pw_all.append(score)

pw_all = np.concatenate(pw_all)

# %%
pw_all.mean()
# Out:
# np.float64(-1.4544564601835692)

# %%
rolling_features_df
# Out:
#       season  week   passer_id        passer  pass_td  n_passes  total_line  team_line  air_yards  interceptions  ...  posteam_type  season_type n_games pass_td_rate  \
# 0       2007     1  00-0004161    J.Delhomme      3.0        30        43.0       -1.5      229.0            0.0  ...          away          REG      13     1.307692
# 1       2007     1  00-0005106       B.Favre      0.0        47        41.5       -3.0      421.0            1.0  ...          home          REG      16     1.125000
# 2       2007     1  00-0005755      J.Garcia      0.0        34        40.5       -6.0      226.0            0.0  ...          away          REG       8     1.500000
# 3       2007     1  00-0006355       T.Green      1.0        42        34.0       -3.0      248.0            0.0  ...          away          REG       9     0.888889
# 4       2007     1  00-0007091  M.Hasselbeck      1.0        28        40.5        6.0      192.0            0.0  ...          home          REG      14     1.500000
# ...      ...   ...         ...           ...      ...       ...         ...        ...        ...            ...  ...           ...          ...     ...          ...
# 9276    2023    21  00-0033873     P.Mahomes      1.0        50        44.0       -4.5      233.0            0.0  ...          away         POST      38     2.052632
# 9277    2023    21  00-0034796     L.Jackson      1.0        47        44.0        4.5      344.0            1.0  ...          home         POST      28     1.535714
# 9278    2023    21  00-0037834       B.Purdy      1.0        36        52.5        7.5      283.0            1.0  ...          home         POST      26     1.846154
# 9279    2023    22  00-0033873     P.Mahomes      2.0        55        47.0       -1.5      280.0            1.0  ...          home         POST      39     2.025641
# 9280    2023    22  00-0037834       B.Purdy      1.0        43        47.0        1.5      324.0            0.0  ...          away         POST      27     1.814815
#
#       air_yards_pg  inteceptions_pg  completions_pg  passing_yards_pg  is_home  is_playoff
# 0       263.384615         0.846154       20.230769        215.769231        0           0
# 1       331.562500         1.125000       21.437500        242.812500        1           0
# 2       274.125000         0.250000       18.375000        209.125000        0           0
# 3       199.555556         1.222222       15.000000        161.000000        0           0
# 4       320.357143         1.285714       17.571429        205.500000        1           0
# ...            ...              ...             ...               ...      ...         ...
# 9276    254.368421         0.684211       24.947368        279.289474        0           1
# 9277    240.857143         0.500000       18.678571        216.464286        1           1
# 9278    218.884615         0.576923       18.538462        248.153846        1           1
# 9279    253.820513         0.666667       25.076923        278.307692        1           1
# 9280    221.259259         0.592593       18.592593        248.851852        0           1
#
# [9281 rows x 22 columns]

# %%
feature_sets = {
    "Basic":  ["pass_td_rate","total_line"],
    "Betting Only": ["total_line","team_line"],
    "Throwing Focus":  ["pass_td_rate", "completions_pg","air_yards_pg","passing_yards_pg","inteceptions_pg"],
    "Situation Focused":  ["total_line", "team_line", "is_home","is_playoff","week"],
    "Everything": ["pass_td_rate", "total_line", "completions_pg","air_yards_pg","passing_yards_pg","inteceptions_pg","team_line", "is_home","is_playoff","n_games","week"],
    "My Best Idea": ["pass_td_rate","total_line","team_line","is_home","air_yards_pg","completions_pg","passing_yards_pg"]
}

# %%
cv_results = {}

kf_random = KFold(n_splits=5,shuffle=True,random_state=65)

for name, cols in feature_sets.items():
    Xm = rolling_features_df[cols].values
    pw_all = []


    for tr, te in kf_random.split(Xm):
        model = PoissonRegressor(alpha=0,max_iter=10000)
        model.fit(Xm[tr],y[tr])
        yhat = model.predict(Xm[te])
        ll = poisson.logpmf(y[te],yhat)
        pw_all.append(ll)

    pw_all = np.concatenate(pw_all)
    cv_results[name] = dict(
        mean_ll = pw_all.mean(),
        se_ll = np.std(pw_all,ddof=1)/np.sqrt(len(pw_all))
    )


cv_results_df = pd.DataFrame(cv_results).T
cv_results_df.index.name="model"

# %%
cv_results_df
# Out:
#                     mean_ll     se_ll
# model
# Basic             -1.454456  0.005925
# Betting Only      -1.450511  0.005864
# Throwing Focus    -1.455874  0.005966
# Situation Focused -1.450429  0.005870
# Everything        -1.441876  0.005882
# My Best Idea      -1.443116  0.005864

# %%
df_sorted = cv_results_df.sort_values("mean_ll",ascending=False)


fig, ax = plt.subplots(figsize=(8,4))
y_pos = range(len(df_sorted))




ax.errorbar(df_sorted["mean_ll"],y_pos,xerr=df_sorted["se_ll"],fmt='o',color=blue)

threshold = df_sorted["mean_ll"].iloc[0] - df_sorted["se_ll"].iloc[0]
ax.axvline(threshold,color=red)

ax.set_yticks(y_pos)
ax.set_yticklabels(df_sorted.index)


ax.invert_yaxis()
plt.tight_layout()
plt.show()

# %%
def plot_cv_comparison(cv_results_df):
    df_sorted = cv_results_df.sort_values("mean_ll",ascending=False)


    fig, ax = plt.subplots(figsize=(8,4))
    y_pos = range(len(df_sorted))




    ax.errorbar(df_sorted["mean_ll"],y_pos,xerr=df_sorted["se_ll"],fmt='o',color=blue)

    threshold = df_sorted["mean_ll"].iloc[0] - df_sorted["se_ll"].iloc[0]
    ax.axvline(threshold,color=red)

    ax.set_yticks(y_pos)
    ax.set_yticklabels(df_sorted.index)


    ax.invert_yaxis()
    plt.tight_layout()
    plt.show()

# %%
plot_cv_comparison(cv_results_df)

# %%
tscv = TimeSeriesSplit(n_splits=16)

for name, cols in feature_sets.items():
    Xm = rolling_features_df[cols].values
    pw_all = []


    for tr, te in tscv.split(Xm):
        model = PoissonRegressor(alpha=0,max_iter=10000)
        model.fit(Xm[tr],y[tr])
        yhat = model.predict(Xm[te])
        ll = poisson.logpmf(y[te],yhat)
        pw_all.append(ll)

    pw_all = np.concatenate(pw_all)
    cv_results[name] = dict(
        mean_ll = pw_all.mean(),
        se_ll = np.std(pw_all,ddof=1)/np.sqrt(len(pw_all))
    )


cv_results_df = pd.DataFrame(cv_results).T
cv_results_df.index.name="model"
# Out:
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/linear_model/_linear_loss.py:333: RuntimeWarning: invalid value encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights

# %%
plot_cv_comparison(cv_results_df)

# %%
tscv = TimeSeriesSplit(n_splits=5)
K = 5

cv_results = {}
for name, cols in feature_sets.items():
    Xm = rolling_features_df[cols].values
    pw_all = []

    full_model = PoissonRegressor(alpha =0 , max_iter=10000)
    full_model.fit(Xm,y)

    mu_full = full_model.predict(Xm)
    L_full = poisson.logpmf(y,mu_full)

    L_folds = np.zeros((len(y),K))


    for k, (tr,te) in enumerate(tscv.split(Xm)):

        model_k = PoissonRegressor(alpha=0,max_iter=10000)
        model_k.fit(Xm[tr],y[tr])
        mu_te = model_k.predict(Xm[te])
        pw_all.append(poisson.logpmf(y[te],mu_te))

        mu_all = model_k.predict(Xm)
        L_folds[:,k] = poisson.logpmf(y,mu_all)

    pw_all = np.concatenate(pw_all)


    bias = (L_full - L_folds.mean(axis=1)).mean()

    cv_results[name] = dict(
        mean_ll = pw_all.mean(),
        corrected_ll = pw_all.mean() + bias
    )


cv_results_df = pd.DataFrame(cv_results).T
cv_results_df.index.name="model"

# %%
cv_results_df
# Out:
#                     mean_ll  corrected_ll
# model
# Basic             -1.466166     -1.465465
# Betting Only      -1.461589     -1.461353
# Throwing Focus    -1.469276     -1.467904
# Situation Focused -1.461658     -1.461201
# Everything        -1.454174     -1.452720
# My Best Idea      -1.455318     -1.454197

# %%
df_sorted = cv_results_df.sort_values("mean_ll",ascending=False)


fig, ax = plt.subplots(figsize=(8,4))
y_pos = range(len(df_sorted))


for i in y_pos:
    ax.plot([df_sorted["mean_ll"].iloc[i],df_sorted["corrected_ll"].iloc[i]],[i,i],color="grey")


ax.scatter(df_sorted["mean_ll"],y_pos,color=orange,label="CV Score")

ax.scatter(df_sorted["corrected_ll"],y_pos,color=blue,label="Bias-Corrected Score")



ax.set_yticks(y_pos)
ax.set_yticklabels(df_sorted.index)

ax.legend()
ax.invert_yaxis()
plt.tight_layout()
plt.show()

# %%
rolling_features_df
# Out:
#       season  week   passer_id        passer  pass_td  n_passes  total_line  team_line  air_yards  interceptions  ...  posteam_type  season_type n_games pass_td_rate  \
# 0       2007     1  00-0004161    J.Delhomme      3.0        30        43.0       -1.5      229.0            0.0  ...          away          REG      13     1.307692
# 1       2007     1  00-0005106       B.Favre      0.0        47        41.5       -3.0      421.0            1.0  ...          home          REG      16     1.125000
# 2       2007     1  00-0005755      J.Garcia      0.0        34        40.5       -6.0      226.0            0.0  ...          away          REG       8     1.500000
# 3       2007     1  00-0006355       T.Green      1.0        42        34.0       -3.0      248.0            0.0  ...          away          REG       9     0.888889
# 4       2007     1  00-0007091  M.Hasselbeck      1.0        28        40.5        6.0      192.0            0.0  ...          home          REG      14     1.500000
# ...      ...   ...         ...           ...      ...       ...         ...        ...        ...            ...  ...           ...          ...     ...          ...
# 9276    2023    21  00-0033873     P.Mahomes      1.0        50        44.0       -4.5      233.0            0.0  ...          away         POST      38     2.052632
# 9277    2023    21  00-0034796     L.Jackson      1.0        47        44.0        4.5      344.0            1.0  ...          home         POST      28     1.535714
# 9278    2023    21  00-0037834       B.Purdy      1.0        36        52.5        7.5      283.0            1.0  ...          home         POST      26     1.846154
# 9279    2023    22  00-0033873     P.Mahomes      2.0        55        47.0       -1.5      280.0            1.0  ...          home         POST      39     2.025641
# 9280    2023    22  00-0037834       B.Purdy      1.0        43        47.0        1.5      324.0            0.0  ...          away         POST      27     1.814815
#
#       air_yards_pg  inteceptions_pg  completions_pg  passing_yards_pg  is_home  is_playoff
# 0       263.384615         0.846154       20.230769        215.769231        0           0
# 1       331.562500         1.125000       21.437500        242.812500        1           0
# 2       274.125000         0.250000       18.375000        209.125000        0           0
# 3       199.555556         1.222222       15.000000        161.000000        0           0
# 4       320.357143         1.285714       17.571429        205.500000        1           0
# ...            ...              ...             ...               ...      ...         ...
# 9276    254.368421         0.684211       24.947368        279.289474        0           1
# 9277    240.857143         0.500000       18.678571        216.464286        1           1
# 9278    218.884615         0.576923       18.538462        248.153846        1           1
# 9279    253.820513         0.666667       25.076923        278.307692        1           1
# 9280    221.259259         0.592593       18.592593        248.851852        0           1
#
# [9281 rows x 22 columns]

# %%
num_boot = 1000

n = len(y)

boot_mus = np.zeros(num_boot)

feature_cols = feature_sets["Basic"]

X_base = rolling_features_df[feature_cols].values

boot_coefs = np.zeros((num_boot,2))

X_target = np.array([[1.75,45.5]])


for b in range(num_boot):

    model_boot = PoissonRegressor(alpha=0,max_iter=1000)

    # idx = np.random.choice(n,n,replace=True)
    # model.fit(X_base[idx],y[idx])

    X_boot, y_boot = resample(X_base,y,n_samples=n,random_state=b)
    model_boot.fit(X_boot,y_boot)

    boot_coefs[b,:] = model_boot.coef_

    boot_mus[b] = model_boot.predict(X_target)[0]
# Out:
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(
# /home/georgehagstrom/miniforge3/envs/DATA622/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but PoissonRegressor was fitted with feature names
#   warnings.warn(

# %%
mu_high, mu_low = np.percentile(boot_mus,[4,96.0])
[mu_high,mu_low]
# Out:
# [np.float64(1.5492028472399906), np.float64(1.595785698375766)]

# %%
[1-poisson.cdf(1,mu_high),1-poisson.cdf(1,mu_low)]
# Out:
# [np.float64(0.4585053788695378), np.float64(0.47370661398197467)]

# %%
[np.percentile(boot_coefs[:,0],4),np.percentile(boot_coefs[:,0],96)]
[np.percentile(boot_coefs[:,1],4),np.percentile(boot_coefs[:,1],96)]
# Out:
# [np.float64(0.019485408770136867), np.float64(0.02630447242613719)]
